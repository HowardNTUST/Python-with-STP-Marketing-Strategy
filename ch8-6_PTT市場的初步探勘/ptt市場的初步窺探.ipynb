# %% [markdown]
# # STP 行銷策略之 Python 商業應用實戰專書
# # 章節 8-6 市場的初步探勘
#
# - author: [鍾皓軒](https://tmrmds.co/about/)與楊超霆
# - 建議讀者可以配合[STP 行銷策略之 Python 商業應用實戰](https://www.tenlong.com.tw/products/9789865025878?list_name=b-r7-zh_tw)專書的章節 8-6 市場的初步探勘一同參考，效果會更好

# %% [markdown]
# ## PTT資料
# 本章節為更確定市場區隔與市場目標對服務業者的正確性，即再以PTT資料進行爬取確認，本章節會以PTT資料為主進行簡易的探勘，所以並不會提及PTT爬蟲技巧，單若想了解如何爬取PTT的資料，歡迎參考下述2篇文章教學
# - [【資料蒐集】 Python網路爬蟲專案導向教學](https://medium.com/marketingdatascience/%E7%95%B6stp-%E8%A1%8C%E9%8A%B7%E7%AD%96%E7%95%A5-%E9%81%87%E5%88%B0%E8%B3%87%E6%96%99%E7%A7%91%E5%AD%B8-%E7%B3%BB%E5%88%973-%E8%B3%87%E6%96%99%E8%92%90%E9%9B%86-python%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2%E5%B0%88%E6%A1%88%E5%B0%8E%E5%90%91%E6%95%99%E5%AD%B8-698fd55fd73d)
# - [【資料蒐集】PTT貼文抓取模組教學](https://medium.com/marketingdatascience/%E7%95%B6stp-%E8%A1%8C%E9%8A%B7%E7%AD%96%E7%95%A5-%E9%81%87%E5%88%B0%E8%B3%87%E6%96%99%E7%A7%91%E5%AD%B8-%E7%B3%BB%E5%88%974-%E8%B3%87%E6%96%99%E8%92%90%E9%9B%86-ptt%E8%B2%BC%E6%96%87%E6%8A%93%E5%8F%96%E6%A8%A1%E7%B5%84%E6%95%99%E5%AD%B8-fcd94c05ad41)

# %% [markdown]
# ## 事前準備
# 取得[PTT檔案](https://drive.google.com/file/d/1t0cYLT8Z_zozxartwUxKpaVvuiEnm_fA/view?usp=sharing)

# %%
import pandas as pd
import numpy as np
import platform

# 可以使用pip install opencc-python-reimplemented 安裝
from opencc import OpenCC

# 可以使用pip install maxminddb-geolite2 安裝
from geolite2 import geolite2
geo = geolite2.reader()
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.rcParams['axes.unicode_minus'] = False
colrogroup = ['#427f8f','#4a8fa1','#559db0','#66a7b8','#77b1c0','#89bbc8','#9ac5d0','#bdd9e0','#cee3e8','#e0edf0']
colorcompetitor = ['#d9f776','#76f794','#9476f7','#f776d9','#e70e4b','#76d9f7','#f79476','#fbccbe','#befbcc','#fbbeed']
 
myfont = FontProperties(fname= 'msj.ttf')

# %%
alldata = pd.read_csv('pttData.csv',encoding = 'utf-8-sig')

#--- 挑出提到「運動內衣」相關的標題、文章
underwearData = alldata[alldata['標題'].str.contains("運動內衣") |
                        alldata['標題'].str.contains("運動bra") |
                        alldata['內文'].str.contains("運動內衣") |
                        alldata['內文'].str.contains("運動bra") 
                        ]

# %%
alldata
# Out:
# .1578326949.A.F9A
# 19534        1929             0  M.1578326367.A.622
# 19535        1930             1  M.1578326132.A.136
# 19536        1931             2  M.1578326086.A.A14
# 19537        1932             3  M.1578325434.A.03B
# 19538        1933             4  M.1578325123.A.8C1
# 19539        1934             5  M.1578324771.A.528
# 19540        1935             6  M.1578324701.A.E41
# 19541        1936             7  M.1578324152.A.6BE
# 19542        1937             8  M.1578324045.A.4DC
# 19543        1938             9  M.1578322941.A.FD5
# 19544        1939            10  M.1578321667.A.DE2
# 19545        1940            11  M.1578321419.A.764
# 19546        1941            12  M.1578320950.A.F1B
# 19547        1942            13  M.1578320843.A.A0C
# 19548        1943            14  M.1578320192.A.8EE
# 19549        1944            15  M.1578320187.A.459
# 19550        1945            16  M.1578319273.A.7C5
# 19551        1946            17  M.1578319183.A.102
# 19552        1947            18  M.1578318701.A.299
# 19553        1948            19  M.1578318231.A.738
#
#                                        作者          版名   分類  \
# 0                         hydra60319 (收收)  BabyMother   公告
# 1                         hydra60319 (收收)  BabyMother   公告
# 2                           q82465 (小咪媽咪)  BabyMother   寶寶
# 3                     TwoSeam5566 (二縫線型男)  BabyMother   分享
# 4                          blueshelf (張太)  BabyMother   寶寶
# 5                       sleepingcat3 (睡喵)  BabyMother   寶寶
# 6                              cutilis ()  BabyMother   寶寶
# 7                       oajamie (oajamie)  BabyMother   寶寶
# 8                            ann3222 (芋泥)  BabyMother  NaN
# 9                    bigapple (Big Apple)  BabyMother   寶寶
# 10                     heyregina (regina)  BabyMother   寶寶
# 11                          argustin (  )  BabyMother   懷孕
# 12                        dodobaho (dodo)  BabyMother  NaN
# 13                        coldrose (ROSE)  BabyMother   懷孕
# 14                           nadina (甜美啊)  BabyMother  NaN
# 15                            iamis (包子臉)  BabyMother   寶寶
# 16                          Ssweetie (透明)  BabyMother   寶寶
# 17                    minatoku (minatoku)  BabyMother   心得
# 18                      ortner (OREO香草夾心)  BabyMother   寶寶
# 19                            ohno (    )  BabyMother   寶寶
# 20                        yiada (一起穿一件雨衣)  BabyMother   寶寶
# 21                a078719079 (a078719079)  BabyMother   寶寶
# 22                            sogoso (^^)  BabyMother   問題
# 23                     larac (櫃子裡遊戲永遠少一套)  BabyMother   心得
# 24                      ChicarHui (Minky)  BabyMother   懷孕
# 25              kilayweiwei (初級小秘書養成中'ω')  BabyMother   春聯
# 26                         nice77412 (欸啦)  BabyMother   好康
# 27                            kagaya (~~)  BabyMother   問題
# 28                          yaya0830 (跳跳)  BabyMother   寶寶
# 29                           ggqueen (小雞)  BabyMother   寶寶
# ...                                   ...         ...  ...
# 19524                  AppleMan (敵人就在竹林寺)   WomenTalk   閒聊
# 19525                        kuso0516 (隱)   WomenTalk   討論
# 19526                  AppleMan (敵人就在竹林寺)   WomenTalk   閒聊
# 19527                         jasonn98 ()   WomenTalk   新聞
# 19528                        redDest (油油)   WomenTalk   心情
# 19529                         Faye88 (地圖)   WomenTalk   問題
# 19530                  A816 (七瀬丸和文乃的理想老公)   WomenTalk   閒聊
# 19531                a6234709 (矮醜魯肥宅之代言人)   WomenTalk   心情
# 19532                 s9221320 (金庸大爺忠實粉絲)   WomenTalk   心情
# 19533                       sammoon (sam)   WomenTalk   閒聊
# 19534                 johdju88 (乂不貪污ㄉ阿扁乂)   WomenTalk   閒聊
# 19535                 johdju88 (乂不貪污ㄉ阿扁乂)   WomenTalk   問題
# 19536                    doris520 (doris)   WomenTalk   閒聊
# 19537                  jimabc (Je t'aime)   WomenTalk   問題
# 19538                    zMidTwo5566 (中二)   WomenTalk   問題
# 19539                 catvvine (catvvine)   WomenTalk   閒聊
# 19540                 s9221320 (金庸大爺忠實粉絲)   WomenTalk   心情
# 19541                     genieliao (mia)   WomenTalk   問題
# 19542                    ericgary (艾瑞克蓋瑞)   WomenTalk   閒聊
# 19543                sky9527 (歡迎來到Sky大舞廳)   WomenTalk   閒聊
# 19544                         zhxl (武裝肥宅)   WomenTalk   討論
# 19545                      kamelol (kame)   WomenTalk   閒聊
# 19546                  flower42 (栗悟飯與龜波功)   WomenTalk   閒聊
# 19547                   Macie1998 (Macie)   WomenTalk   心情
# 19548                     apple510 (PuKi)   WomenTalk   閒聊
# 19549                    poonebetty (小肥媽)   WomenTalk   閒聊
# 19550  lpbrother (LP哥(LP = Love & Peace))   WomenTalk   閒聊
# 19551                       iamsheep (??)   WomenTalk   討論
# 19552                      Francise (棉花羊)   WomenTalk   討論
# 19553                       simon78410 ()   WomenTalk   討論
#
#                                   標題  \
# 0                   [公告] 請小心隱藏葉配及假推薦
# 1                       [公告] 找尋群組集中文
# 2          [寶寶] 2018新制育兒津貼和托育補助變化總整理
# 3      [分享] 變態鎖定觀看YouTube孩童 (已知資訊整理)
# 4                     [寶寶] 讓人困擾的大便問題
# 5           Re: [寶寶] 武漢肺炎擴散到各國了，請戴口罩
# 6                   [寶寶] 怎麼提供安撫奶嘴比較好
# 7                [寶寶] 請問LTD包巾要準備幾件替換
# 8                            請問帶寶寶出國
# 9           Re: [寶寶] 武漢肺炎擴散到各國了，請戴口罩
# 10              [寶寶] 大家的2-3歲小孩都多久才睡覺
# 11                [懷孕]  請問板橋豐禾婦產科生產？
# 12                     Re: 該來的那天還是來了
# 13                   [懷孕]  醫生說胚胎沒有長大
# 14                 神一位媽媽唸故事的YouTuber
# 15                 [寶寶] 春滿花開/素面紅包袋彩繪
# 16           [寶寶] ibon輕鬆上手，我的超萌小孩紅包袋
# 17      [心得] 異膚寶乳液（理膚/艾芙美/vanicrerm）
# 18               [寶寶] 求助寶寶厭奶真的要換奶粉嗎?
# 19                     [寶寶]  突然不喜歡上學
# 20                 [寶寶] 請問是異膚還是黴菌感染？
# 21                  [寶寶] 女豬寶寶命名請益（陳）
# 22                  [問題] 嘉義月子中心請益-康寶
# 23                [心得] 日文兒歌改編《喵咪氣象局》
# 24                      [懷孕] 板橋婦產科推薦
# 25                    [春聯] 春節活動-手作春聯
# 26                     [好康] 媽媽禮兌換/屏東
# 27              [問題] 娘家充滿絛蟲跳蚤，過年怎麼辦…
# 28                        [寶寶] 親餵調作息
# 29                    [寶寶] 如何在白天增加奶量
# ...                              ...
# 19524                  [閒聊] 高雄哪裡比較好玩
# 19525          Re: [討論] 男生其實比較喜歡女生素顏
# 19526                     [閒聊] 台中人請近
# 19527    [新聞] 過年換新鈔！全台454金融據點1/16起開放
# 19528                     [心情] 新宿無碼照
# 19529                [問題] 訂婚一定要在家裡辦嗎
# 19530                 [閒聊] 憾!白石麻衣畢業!
# 19531           Re: [心情] 到底怎麼克服怕鬼啦QQ
# 19532                 [心情] 韓國生活好像很恐怖
# 19533  Re: [閒聊] 鹹酥雞吃150元在女孩兒這邊是什麼等級？
# 19534         [閒聊] 個資真的值錢嗎  還是行銷的騙術？
# 19535                     [問題] 關於睡覺？
# 19536       [閒聊] 洗臉皂、洗面乳、潔顏慕斯哪個適合乾燥肌
# 19537              Re: [問題] 當媽媽的代理孕母
# 19538                        [問題] 頂樓
# 19539              Re: [閒聊] 想會什麼第二外語
# 19540           [心情] 同事下班讀書過了歐洲語高級檢定
# 19541          [問題] 公廁私自上鎖。並貼上威商公司專用
# 19542        [閒聊] 男生要刺青刺什麼圖案 女生才會喜歡？
# 19543             [閒聊] 女生的衣服在多什麼意思的？
# 19544              [討論] 男生其實比較喜歡女生素顏
# 19545                [閒聊] 女裝扮相最美的男演員
# 19546               [閒聊] 每年都花多少包紅包？？
# 19547               [心情] 到底怎麼克服怕鬼啦QQ
# 19548             [閒聊] 大家春聯紅包袋都準備好了嗎
# 19549                 [閒聊] 馮提莫為什麼那麼紅
# 19550        Re: [閒聊] 這些歌竟然已經20年了...
# 19551                   [討論] 有胖的帥哥嗎?
# 19552    Re: [討論] 大家有看什麼中國Youtuber嗎？
# 19553         [討論] 希望門鎖和車鑰匙都整合在手機裡嗎?
#
#                                                       內文  \
# 0      \n各位晚安\n\n\n近日有得到一些關於葉配的小八卦\n\n版上的葉配常見有\n\n<sp...
# 1      \n各位早安\n\n\n從今日起，群組文變更成<span class="f1 hl">限定週...
# 2      2019最新圖文好讀版: <a href="http://q82465.pixnet.net...
# 3      各位板友好，小弟剛寫完一篇變態卡通（ElsaGate）相關資訊的整理文（文長），\n剛剛爬了...
# 4      女兒現在八個月大\n前陣子中耳炎吃完抗生素後大便突然成形\n在此之前都有點糊糊泥狀\n而且之...
# 5      其實不需要用到N95口罩，N95真的非常難呼吸，沒辦法戴很久的。\n\n請使用一般的外科口罩...
# 6      請問各位親餵媽媽怎麼給寶寶安撫奶嘴？\n\n我的寶寶6週大，口慾強，目前ㄧ半親餵ㄧ半瓶餵。\...
# 7      各位媽媽好，目前31週，預產期三月中，開始要準備寶寶的東西，想請問大家很推的LTD\n包巾要...
# 8      想請問如果想帶寶寶去東南亞適合嗎\n應該會是跟團 寶寶已一歲 喝早晚奶而已\n目前考慮峴港跟...
# 9      原文恕刪\n\n我今天搭高鐵出差，因為很臨時所以刷悠遊卡\n車到板橋前就廣播人很多，所以開放...
# 10     每天陪睡都陪到厭世\n除非當天沒午睡，不然一定一小時起跳\n\n覺得女兒最厲害的地方就是她可...
# 11     本來在板橋育馨診所胡醫師產檢\n但胡醫師說因生涯規劃要離職了\n沒透露要去哪裡\n請我找別的...
# 12     其實我很能體會你那種，很捨不得孩子，但現實上，又不是擁有親權的苦，即使現實上你可能比他媽媽還...
# 13     月經週期約27-30天\n算是蠻規律來的，不是高齡\n\n12/8是最後一次月經\n\n1/...
# 14     很久之前在這裡看到，\n內容是一位媽媽跟女兒唸繪本，\n媽媽的聲音很好聽，\n女兒會插話，\...
# 15     <a href="https://i.imgur.com/jZoP3YF.jpg" rel=...
# 16        圖文網誌版：<a href="https://reurl.cc/0zry3l" rel...
# 17     小孩屬於比較輕微的異位性皮膚炎\n通常是局部或特定區域容易紅紅粗粗的程度\n對異膚乳液也算是...
# 18     目前寶寶七個多月\n\n原本四個小時可以喝180cc，但現在喝50cc就不願意喝\n\n已經...
# 19     我女兒去年9月開始上小班，一開始還蠻喜歡去學校的，但是從今年開始，就開始說不想\n去上學，但...
# 20     \n寶寶目前3m13D\n之前甲溝炎到兒科診所看診\n有針對寶寶皮膚的問題請教醫生\n當時醫...
# 21     目前跟家人討論出的名字有三個\n麻煩大家看看如何\n1.畇希\n2.映橦\n3.畇菫\n\n...
# 22     問了好幾間熱門的月子中心都滿了，\n\n終於問到康寶還有，\n\n不過似乎查不到評價，\n\...
# 23                    \n趁著鼠年來到前趕緊分享這首貓貓歌 XD\n\n自彈自唱影音檔在這
# 24     代問\n本身經期不穩定，上週有出血以為是月經來\n但量很少一下有一下沒有，就去附近掛號看診，...
# 25     今天是新的PG共學團首次聚會(也是年節前最後一次)，趁著記憶猶新來紀錄一下今天的手\n作活動...
# 26     哈囉 各位媽咪~在媽寶板潛水已久 來分享一下~\n今天產檢 順便在（屏東市區）換媽媽禮\n再...
# 27     \n寶寶1.5歲\n\n娘家有養三隻貓\n過年前去幫媽媽大掃除\n發現家裡貓窩都是絛蟲的節片...
# 28     \n寶寶現在5m全親餵\n小睡哭鬧只睡30分鐘\n晚上有睡過夜10小時過\n平常大概要夜奶個...
# 29     \n女寶寶剛滿4個月5.5kg.\n目前都是每4小時喝奶120-150ml，半夜也是會起來，...
# ...                                                  ...
# 19524  \n\n\n說道高雄的知名景點\n小妹只知道\n\n1.85大樓\n\n2.愛河\n\n3....
# 19525  <span class="f2">※ 引述《zhxl (武裝肥宅)》之銘言：\n</span...
# 19526  \n\n\n小妹的G軟老公是葛台中人\n他好像很喜歡吃慶記der東C\n所以小妹也想去吃看看...
# 19527  \n\n新聞標題：\n\n過年換新鈔！全台454金融據點1/16起開放兌換\n\n新聞內容：...
# 19528  就是在新宿jr出來的陸橋有人上吊的照片\n\n油油我有看到沒有馬賽克的版本\n\n是說也沒有...
# 19529  \n我另一半說  訂婚一定要在家裡辦 不然會很奇怪 他完全無法接受\n\n我說現在有很多在外...
# 19530  \n太難受了\n\n我真的太難受了\n\n我的青春就這樣結束了\n\n從11年一直看著到今年...
# 19531  這簡單~\n一堆文章表述飄飄雖然會出來嚇人 但起碼都有不少神明出手擋下來(才可以把故事寫出來...
# 19532  我剛看了去韓國youtuber說心裡話\n因為其它全部youtuber都很夭壽只講好話,騙人...
# 19533  <span class="f2">※ 引述《miss80423 (自宅警備員)》之銘言：\n...
# 19534  如題\n\n\n有一款瀏覽器叫做duckduckgo  主打保護你的隱私\n\n聲稱說goo...
# 19535  \n以前只要我很想要睡著  就會完全睡不著  明明也乖乖躺著\n\n而且試著想一些放鬆的東西...
# 19536  到冬天臉上必脫皮，\n嚴重到上班都得整天戴口罩，\n更慘的是最近變冷之後，\n下班騎車回家臉...
# 19537  \n先幫原PO拍拍 你要提早習慣台灣這種假道學社會\n\n雖然已經開放同性婚姻 但是關於人工...
# 19538  \n加蓋\n\n有人住過嗎？\n\n房東說上面有一層隔熱層\n變成沒有想像的那麼熱\n\n大...
# 19539  <span class="f2">※ 引述《AngryYouth (森寶 420friend...
# 19540  有個同事最近剛過外語的高級檢定\n讓我有點驚訝\n那是算是很高程度流利度的外語檢定\n\n原...
# 19541  大家好。第一次在這個版貼文。希望大家評評理\nPs文很長\n\n去年5月。公司搬遷到台北市某...
# 19542  \n三重蘆洲有一些8+9刺青\n\n刺龍刺虎\n\n女生看到都很反感 覺得很醜 很台\n\n...
# 19543  \n欸欸就是\n\n最近在幫忙整理家裡啦\n\n啊發現為啥女生的衣服那麼多啊\n\n幹滿坑滿...
# 19544  很多女生拼了命得化妝\n\n可是身為男生其實大部分都比較偏好素顏\n\n十個男生有八個都比較...
# 19545  \n\n之前在追從前有座靈劍山時，許凱的女裝扮相讓我超驚艷!!\n\n超美的啊，五官也太精緻...
# 19546               過年又到了\n也代表要包給晚輩了QQ\n\n大家每年都花多少在紅包上呢？
# 19547  安安大家\n\n我從小就超級怕鬼\n\n雖然沒看過\n\n但總覺得它隨時會冒出來\n\n本大...
# 19548  如題～\n過年快到了\n因為春聯跟紅包袋都希望能找自己看了賞心悅目的\n尤其是春聯！！！貼在...
# 19549  只是一個網紅\n會唱歌\n沒有比歌手會唱啊\n看她跟張韶涵\n<a href="https:...
# 19550  \n剛好聽到這首\n\n江美琪 的 我多麼羨慕你\n\n\n收錄於 1999 年 12月 的...
# 19551  現在主流審美觀都要瘦子\n\n帥哥沒聽過有胖子的\n\n胖正妹倒是有\n\n有人能舉例哪個男...
# 19552  推薦一個療癒中國Youtuber\n\n"好奇五先生"，不曉得各位有沒有看過\n\n這You...
# 19553  各位女孩兒們早安 我是正在吃愛心早餐的屎門門\n\n剛光出門時又忘了帶鑰匙 害我急急忙忙地從...
#
#                              日期            IP位置  總留言數   噓     推   中立  \
# 0      Mon Apr 15 18:55:01 2019   220.141.22.15   121   0    59   62
# 1      Thu Dec 20 07:14:04 2018  220.141.24.136  1290   0  1145  145
# 2      Wed Jul 25 11:18:58 2018  149.117.216.29   348   1   159  188
# 3      Sun Jan 21 20:16:48 2018  140.112.217.55   149   1    86   62
# 4      Wed Jan 22 00:29:02 2020            (臺灣)     4   0     2    2
# 5      Wed Jan 22 00:08:43 2020            (臺灣)     2   0     1    1
# 6      Tue Jan 21 23:50:26 2020            (美國)     8   0     2    6
# 7      Tue Jan 21 23:18:54 2020            (臺灣)    34   0    21   13
# 8      Tue Jan 21 23:17:34 2020            (臺灣)    10   0     4    6
# 9      Tue Jan 21 23:13:50 2020            (臺灣)    16   1     8    7
# 10     Tue Jan 21 23:10:20 2020            (臺灣)    42   0    17   25
# 11     Tue Jan 21 23:07:18 2020            (臺灣)     2   0     1    1
# 12     Tue Jan 21 21:58:16 2020            (臺灣)     5   0     5    0
# 13     Tue Jan 21 21:04:43 2020            (臺灣)    23   0    14    9
# 14     Tue Jan 21 20:17:04 2020            (臺灣)     1   0     1    0
# 15     Tue Jan 21 20:10:58 2020            (臺灣)     8   0     7    1
# 16     Tue Jan 21 20:03:57 2020            (臺灣)    10   0     7    3
# 17     Tue Jan 21 19:55:53 2020            (臺灣)     5   0     4    1
# 18     Tue Jan 21 19:12:33 2020            (臺灣)    18   0     8   10
# 19     Tue Jan 21 17:37:14 2020            (法國)     5   0     1    4
# 20     Tue Jan 21 17:37:10 2020            (臺灣)    17   0     9    8
# 21     Tue Jan 21 17:21:33 2020            (臺灣)    18   0     7   11
# 22     Tue Jan 21 17:10:59 2020            (臺灣)    12   0     1   11
# 23     Tue Jan 21 17:04:14 2020            (臺灣)     2   0     2    0
# 24     Tue Jan 21 16:43:51 2020            (臺灣)    28   0    17   11
# 25     Tue Jan 21 16:43:07 2020            (臺灣)     4   0     1    3
# 26     Tue Jan 21 16:32:43 2020            (臺灣)     4   0     4    0
# 27     Tue Jan 21 15:55:40 2020            (臺灣)   105   0    43   62
# 28     Tue Jan 21 15:52:48 2020            (臺灣)    10   0     7    3
# 29     Tue Jan 21 15:43:47 2020            (臺灣)    10   0     2    8
# ...                         ...             ...   ...  ..   ...  ...
# 19524  Tue Jan  7 00:42:27 2020            (臺灣)    10   0     4    6
# 19525  Tue Jan  7 00:42:20 2020            (臺灣)     5   1     2    2
# 19526  Tue Jan  7 00:37:36 2020            (臺灣)     4   1     2    1
# 19527  Tue Jan  7 00:36:53 2020            (韓國)     1   0     1    0
# 19528  Tue Jan  7 00:29:30 2020            (臺灣)     4   0     1    3
# 19529  Tue Jan  7 00:27:26 2020             來自:    18   0     7   11
# 19530  Tue Jan  7 00:21:11 2020            (臺灣)     6   2     2    2
# 19531  Tue Jan  7 00:13:40 2020            (臺灣)     6   0     2    4
# 19532  Tue Jan  7 00:13:27 2020           (加拿大)   200   3    65  132
# 19533  Tue Jan  7 00:09:07 2020            (臺灣)    14   1     7    6
# 19534  Mon Jan  6 23:59:25 2020            (日本)    28   0     9   19
# 19535  Mon Jan  6 23:55:30 2020            (日本)     5   1     3    1
# 19536  Mon Jan  6 23:54:44 2020            (臺灣)    17   0     7   10
# 19537  Mon Jan  6 23:43:51 2020            (臺灣)    36   3     7   26
# 19538  Mon Jan  6 23:38:39 2020            (臺灣)    18   1     9    8
# 19539  Mon Jan  6 23:32:49 2020            (臺灣)    13   1     7    5
# 19540  Mon Jan  6 23:31:39 2020           (加拿大)    66   0    29   37
# 19541  Mon Jan  6 23:22:30 2020            (臺灣)    93   1    42   50
# 19542  Mon Jan  6 23:20:43 2020            (臺灣)    25   2    12   11
# 19543  Mon Jan  6 23:02:19 2020            (臺灣)     6   2     0    4
# 19544  Mon Jan  6 22:41:05 2020            (臺灣)   394  49   121  224
# 19545  Mon Jan  6 22:36:57 2020            (臺灣)    29   0    18   11
# 19546  Mon Jan  6 22:29:08 2020            (臺灣)     9   0     2    7
# 19547  Mon Jan  6 22:27:21 2020            (臺灣)   192   3    87  102
# 19548  Mon Jan  6 22:16:30 2020            (臺灣)     8   0     6    2
# 19549  Mon Jan  6 22:16:25 2020            (臺灣)    23   0     6   17
# 19550  Mon Jan  6 22:01:11 2020            (臺灣)    14   0     6    8
# 19551  Mon Jan  6 21:59:41 2020            (臺灣)    17   0     8    9
# 19552  Mon Jan  6 21:51:39 2020            (臺灣)     6   0     2    4
# 19553  Mon Jan  6 21:43:46 2020            (美國)    13   0     3   10
#
#        文章分數（正-負）                                               所有留言
# 0             59  [{'type': '推', 'user': 'selfhsuan', 'content':...
# 1           1145  [{'type': '推', 'user': 'connie27', 'content': ...
# 2            158  [{'type': '推', 'user': 'ammou', 'content': '覺得...
# 3             85  [{'type': '推', 'user': 'fm', 'content': '推', '...
# 4              2  [{'type': '推', 'user': 't39933', 'content': '我...
# 5              1  [{'type': '推', 'user': 'Isotopes', 'content': ...
# 6              2  [{'type': '推', 'user': 'fnun', 'content': '熟睡掉...
# 7             21  [{'type': '推', 'user': 'layslv', 'content': '我...
# 8              4  [{'type': '推', 'user': 'angelstar', 'content':...
# 9              7  [{'type': '→', 'user': 'trueblend', 'content':...
# 10            17  [{'type': '推', 'user': 'daiting', 'content': '...
# 11             1  [{'type': '推', 'user': 'YuBoMei', 'content': '...
# 12             5  [{'type': '推', 'user': 'eva780913', 'content':...
# 13            14  [{'type': '推', 'user': 'orangeaka', 'content':...
# 14             1  [{'type': '推', 'user': 'ryulove', 'content': '...
# 15             7  [{'type': '推', 'user': 'ilyforever', 'content'...
# 16             7  [{'type': '推', 'user': 'tsaishen', 'content': ...
# 17             4  [{'type': '推', 'user': 'sweetsandy', 'content'...
# 18             8  [{'type': '推', 'user': 'kiki520', 'content': '...
# 19             1  [{'type': '→', 'user': 'memorymiku', 'content'...
# 20             9  [{'type': '推', 'user': 'cya81', 'content': '看起...
# 21             7  [{'type': '推', 'user': 'RoadStar', 'content': ...
# 22             1  [{'type': '推', 'user': 'icerainni', 'content':...
# 23             2  [{'type': '推', 'user': 'TS501', 'content': '推推...
# 24            17  [{'type': '推', 'user': 'secret929', 'content':...
# 25             1  [{'type': '推', 'user': 'iamis', 'content': '謝謝...
# 26             4  [{'type': '推', 'user': 'andrea0520', 'content'...
# 27            43  [{'type': '推', 'user': 'bigant', 'content': '體...
# 28             7  [{'type': '推', 'user': 'superer', 'content': '...
# 29             2  [{'type': '推', 'user': 'miss0409', 'content': ...
# ...          ...                                                ...
# 19524          4  [{'type': '→', 'user': 'Beanoodle', 'content':...
# 19525          1  [{'type': '推', 'user': 'a94037501', 'content':...
# 19526          1  [{'type': '→', 'user': 'HDSM', 'content': '慶記'...
# 19527          1  [{'type': '推', 'user': 'Superxixai', 'content'...
# 19528          1  [{'type': '→', 'user': 'a94037501', 'content':...
# 19529          7  [{'type': '推', 'user': 'sylvia25856', 'content...
# 19530          0  [{'type': '推', 'user': 'Iakane', 'content': '老...
# 19531          2  [{'type': '推', 'user': 'mopepe5566', 'content'...
# 19532         62  [{'type': '→', 'user': 's9221320', 'content': ...
# 19533          6  [{'type': '推', 'user': 'Iakane', 'content': '這...
# 19534          9  [{'type': '推', 'user': 'ejcji4sul3', 'content'...
# 19535          2  [{'type': '推', 'user': 'a240daniel', 'content'...
# 19536          7  [{'type': '→', 'user': 'lin91223', 'content': ...
# 19537          4  [{'type': '推', 'user': 'rainwalnut', 'content'...
# 19538          8  [{'type': '→', 'user': 'MM1956', 'content': '只...
# 19539          6  [{'type': '推', 'user': 'TTSENG10', 'content': ...
# 19540         29  [{'type': '推', 'user': 'drajan', 'content': '讀...
# 19541         41  [{'type': '推', 'user': 'ejcji4sul3', 'content'...
# 19542         10  [{'type': '→', 'user': 'wet00428', 'content': ...
# 19543         -2  [{'type': '→', 'user': 'mamajustgo', 'content'...
# 19544         72  [{'type': '噓', 'user': 'kuokuojie', 'content':...
# 19545         18  [{'type': '→', 'user': 'aka11279', 'content': ...
# 19546          2  [{'type': '推', 'user': 'Iakane', 'content': '花...
# 19547         84  [{'type': '→', 'user': 'eva19452002', 'content...
# 19548          6  [{'type': '推', 'user': 'lchun123', 'content': ...
# 19549          6  [{'type': '推', 'user': 'peggy60624', 'content'...
# 19550          6  [{'type': '→', 'user': 'minifat', 'content': '...
# 19551          8  [{'type': '→', 'user': 'minifat', 'content': '...
# 19552          2  [{'type': '→', 'user': 'jameshcm', 'content': ...
# 19553          3  [{'type': '推', 'user': 'lpbrother', 'content':...
#
# [19554 rows x 16 columns]

# %% [markdown]
# ## 運動內衣文章來源

# %%
boardName = underwearData['版名'].value_counts()
plt.figure(figsize=(10,8))
plt.pie(boardName.values, #各比例
        explode= [x//len(boardName)*0.3 for x in range(len(boardName),0,-1)], #散開程度
        labels=boardName.index, #標籤
        autopct='%1.1f%%', #數值格式
        shadow=True, #陰影
        colors = colrogroup, #顏色
        textprops={'fontsize': 14}, #文字大小
        startangle=90 ) #轉向角度）
plt.title("運動內衣文章來源（共"+str(len(underwearData))+"篇）",fontsize=30,fontproperties=myfont)#標題
plt.axis('equal')# 讓圓餅圖畫出來是圓形
plt.tight_layout()

# %% [markdown]
# ## 判斷發文IP位置

# %%
def IP_info(ip):
    try:
        x = geo.get(ip)
        getCH = x['country']['names']['zh-CN']
        
        return OpenCC('s2t').convert(getCH) if x is not None else np.nan
    except:
        if ('(' in ip)  and (')' in ip):
            ip = ip.replace('(','')
            ip = ip.replace(')','')
            return ip
        else:
            return np.nan
        
underwearData['IP位置'] = underwearData['IP位置'].apply(IP_info)

showlocat = underwearData['IP位置'].value_counts()
plt.bar(showlocat.index,showlocat.values,
            color=colrogroup[3],
            alpha=0.5)
plt.title("提到運動內衣的網友位置",fontsize=30,fontproperties=myfont)#標題
plt.ylabel("文章數量",fontsize=20,fontproperties=myfont)#y的標題
plt.xlabel("地區",fontsize=20,fontproperties=myfont) #x的標題
plt.tight_layout()

# %% [markdown]
# ## 發文時間

# %%
# 處理時間
underwearData['日期'] = underwearData['日期'].str.replace('Jan','1')
underwearData['日期'] = underwearData['日期'].str.replace('Feb','2')
underwearData['日期'] = underwearData['日期'].str.replace('Mar','3')
underwearData['日期'] = underwearData['日期'].str.replace('Apr','4') 
underwearData['日期'] = underwearData['日期'].str.replace('May','5')
underwearData['日期'] = underwearData['日期'].str.replace('Jun','6')
underwearData['日期'] = underwearData['日期'].str.replace('Jul','7')
underwearData['日期'] = underwearData['日期'].str.replace('Aug','8')
underwearData['日期'] = underwearData['日期'].str.replace('Sep','9')
underwearData['日期'] = underwearData['日期'].str.replace('Oct','10')
underwearData['日期'] = underwearData['日期'].str.replace('Nov','11')
underwearData['日期'] = underwearData['日期'].str.replace('Dec','12')

underwearData[['星期','日期待轉換']] = underwearData['日期'].str.split(n=1, expand=True)
underwearData['日期'] = pd.to_datetime(underwearData['日期待轉換'])
underwearData = underwearData.drop(columns=['日期待轉換'])

week = underwearData['星期'].value_counts()

# %%
# 繪圖
plt.figure(figsize=(10,8))
plt.pie(week.values, #各比例
        explode= [x//len(week)*0.3 for x in range(len(week),0,-1)], #散開程度
        labels=week.index, #標籤
        autopct='%1.1f%%', #數值格式
        shadow=True, #陰影
        colors = colrogroup, #顏色
        textprops={'fontsize': 14}, #文字大小
        startangle=90 ) #轉向角度）
plt.title("文章時間",fontsize=30,fontproperties=myfont)#標題
plt.axis('equal')# 讓圓餅圖畫出來是圓形
plt.tight_layout()
